# %% [markdown]
# # 🧹 Clean & Transform: PepsiCo Sales and Product Data
#
# This notebook serves as a log and visual inspection step for Phase 2.
# - Load cleaned CSVs from `data/processed/`
# - Confirm column types, structure, and ranges
# - Validate feature engineering results
# - Log shape and statistical summaries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# File paths
stock_path = '../data/processed/pep_stock_clean.csv'
product_path = '../data/processed/pepsico_products_clean.csv'

# Load processed data
df_stock = pd.read_csv(stock_path, parse_dates=['Date'])
df_products = pd.read_csv(product_path)

# Preview
df_stock.head(), df_products.head()

# %%
# Stock dataset inspection
df_stock.info()
df_stock.describe()

# %%
# Product dataset inspection
df_products.info()
df_products.describe(include='all')

# %%
# Confirm engineered fields
df_products[['Product_Name', 'Year_Launched', 'Product_Age_2021', 'Is_Active']].sample(5)
